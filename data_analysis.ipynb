# %% [markdown]
# ## File descriptions
# * train.csv — the training set
# * test.csv — the test set
# * sample_submission.csv — a sample submission file in the correct format
# * cliente_tabla.csv — client names (can be joined with train/test on Cliente_ID)
# * producto_tabla.csv — product names (can be joined with train/test on Producto_ID)
# * town_state.csv — town and state (can be joined with train/test on Agencia_ID)
#
# ## Data fields
# * Semana — Week number (From Thursday to Wednesday)
# * Agencia_ID — Sales Depot ID
# * Canal_ID — Sales Channel ID
# * Ruta_SAK — Route ID (Several routes = Sales Depot)
# * Cliente_ID — Client ID
# * NombreCliente — Client name
# * Producto_ID — Product ID
# * NombreProducto — Product Name
# * Venta_uni_hoy — Sales unit this week (integer)
# * Venta_hoy — Sales this week (unit: pesos)
# * Dev_uni_proxima — Returns unit next week (integer)
# * Dev_proxima — Returns next week (unit: pesos)
# * Demanda_uni_equil — Adjusted Demand (integer) (This is the target you will predict)

# %%
import pandas as pd
import sklearn as skl
import numpy as np

# %%
product_data = pd.read_csv('grupo-bimbo/producto_tabla.csv')
print(product_data.shape)
#product_data.head()
# Out:
# (2592, 2)

# %%
train_data = pd.read_csv('grupo-bimbo/train.csv')
print(train_data.shape)
# Out:
# (74180464, 11)

# %%
train_data.columns
# Out:
# Index(['Semana', 'Agencia_ID', 'Canal_ID', 'Ruta_SAK', 'Cliente_ID',
#        'Producto_ID', 'Venta_uni_hoy', 'Venta_hoy', 'Dev_uni_proxima',
#        'Dev_proxima', 'Demanda_uni_equil'],
#       dtype='object')

# %%
train_data.head()
# Out:
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       3        1110         7      3301       15766         1212
# 1       3        1110         7      3301       15766         1216
# 2       3        1110         7      3301       15766         1238
# 3       3        1110         7      3301       15766         1240
# 4       3        1110         7      3301       15766         1242
#
#    Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  Demanda_uni_equil
# 0              3      25.14                0          0.0                  3
# 1              4      33.52                0          0.0                  4
# 2              4      39.32                0          0.0                  4
# 3              4      33.52                0          0.0                  4
# 4              3      22.92                0          0.0                  3

# %%
temp_df = train_data.groupby('Producto_ID').count()

# %%
temp_df.head()
# Out:
# Producto_ID
# 41         61
# 53        114
# 72     146204
# 73     218851
# 100       124
# Name: Semana, dtype: int64

# %%
for product in temp_df.iteritems():
    
    print('product_ID = ', product[0])
    new_subdf = train_data[train_data['Producto_ID'] == product[0]]
    filepath = 'grupo-bimbo/products/' + str(product[0]) + '.csv'
    
    new_subdf.to_csv(filepath, index=False)
# Out:
# product_ID =  41
# product_ID =  53
# product_ID =  72
# product_ID =  73
# product_ID =  100
# product_ID =  106
# product_ID =  107
# product_ID =  108
# product_ID =  122
# product_ID =  123
# product_ID =  131
# product_ID =  132
# product_ID =  134
# product_ID =  135
# product_ID =  141
# product_ID =  145
# product_ID =  151
# product_ID =  157
# product_ID =  160
# product_ID =  162
# product_ID =  163
# product_ID =  183
# product_ID =  202
# product_ID =  205
# product_ID =  214
# product_ID =  217
# product_ID =  303
# product_ID =  306
# product_ID =  323
# product_ID =  325
# product_ID =  328
# product_ID =  357
# product_ID =  412
# product_ID =  630
# product_ID =  632
# product_ID =  634
# product_ID =  635
# product_ID =  641
# product_ID =  665
# product_ID =  693
# product_ID =  713
# product_ID =  714
# product_ID =  715
# product_ID =  739
# product_ID =  779
# product_ID =  815
# product_ID =  890
# product_ID =  972
# product_ID =  1039
# product_ID =  1064
# ...

# %%
df_41 = pd.read_csv('grupo-bimbo/products/41.csv')
df_41.head(20)
# Out:
#     Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0        3        2281         7      3303      684023           41
# 1        3        2281         7      3306      681747           41
# 2        3        2281         7      3306      685079           41
# 3        3        2281         7      3306     1623763           41
# 4        3        2281         7      3309     1035265           41
# 5        3        2281         7      3309     2482890           41
# 6        3       23879         7      3201     1546790           41
# 7        3       23879         7      3201     4586525           41
# 8        4        2281         7      3303      684023           41
# 9        4        2281         7      3303     1938075           41
# 10       4        2281         7      3306      681747           41
# 11       4        2281         7      3306      685079           41
# 12       4        2281         7      3306     1623763           41
# ...

# %%
test_data = pd.read_csv('grupo-bimbo/test.csv')
print(test_data.shape)
#test_data.head()
# Out:
# (6999251, 7)

# %%
test_data.columns
# Out:
# Index(['id', 'Semana', 'Agencia_ID', 'Canal_ID', 'Ruta_SAK', 'Cliente_ID',
#        'Producto_ID'],
#       dtype='object')

# %%
client_data = pd.read_csv('grupo-bimbo/cliente_tabla.csv')
print(client_data.shape)
#client_data.head()
# Out:
# (935362, 2)

# %%
product_data.columns = ['product_id', 'product_name']
product_data.columns
# Out:
# Index(['product_id', 'product_name'], dtype='object')
